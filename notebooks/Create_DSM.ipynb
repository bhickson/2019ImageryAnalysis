# %% [markdown]
# ## EPC Extent

# %%
# %%time
# %load_ext chime

import os
import pdal
import gdal
from datetime import datetime
import json
import rasterio as rio
from joblib import Parallel, delayed

json_pipe_base = """ { "pipeline": [ %s ] } """

gdal_writer = """
    "%s",
    {
        "type":"writers.gdal",
        "filename": "%s",
        "resolution": %s,
        "window_size": %s,
        "nodata": 0,
        "output_type": "idw",
        "gdalopts":"TILED=YES, COMPRESS=LZW"
    }
"""

def createDSM(file_dict, res, overwrite=False):
    infile = file_dict["in_file"]
    outfile = file_dict["out_file"]
    
    if os.path.exists(outfile) and not overwrite:
        return
  
    json_dsm = gdal_writer % (infile.replace("\\","/"), outfile.replace("\\","/"), res, max(res * 2,10))#, ox, oy)#, raswidth, rasheight)
    json_dsm = json_pipe_base % json_dsm
    
    pipeline = pdal.Pipeline(json_dsm)
    pipeline.loglevel = 8

    start = datetime.now()
    pipeline.execute()
    end = datetime.now()

    print(f"{datetime.now()}\t-\tFinished with {outfile} - {end-start} elapsed")


resolution = 0.8/0.3048
resolution_cm = round(resolution*.3048*100)

laz_folder = r"F:/2019_EPCExtent_30cm_rd01/40cm_sgm/RGB/Full"
dsm_folder = f"R:\ProjectData\PAG2019\EPCExtent_30cm\Elevation_80cmNPS\DSM_{resolution_cm}cm"
os.makedirs(dsm_folder, exist_ok=True)

infiles = []
for f in os.listdir(laz_folder):
    infile = os.path.join(laz_folder, f)
    outfile = os.path.join(dsm_folder, f.replace(".laz", f"_DSM{resolution_cm}cm.tif"))
    if f.endswith(".laz"):# and not os.path.exists(outfile):
        files = {}
        files["in_file"] = infile
        files["out_file"] = outfile
        infiles.append(files)

print("\nBeginning DSM Generations for {} QQuads\n".format(len(infiles)))
Parallel(n_jobs=7, max_nbytes=None, verbose=30)(delayed(createDSM)(f, resolution) for f in infiles)
for f in infiles:
    hour = int(datetime.strftime(datetime.now(), '%H'))
    #while hour > 9 and hour < 17:
    #    print("Pausing creation for 1 hours...")
    #    time.sleep(60*60)
    #    hour = int(datetime.strftime(datetime.now(), '%H'))    
    #createDSM(f, resolution)
    
print("\n\n...FINISHED\n\n")

# %chime
# Out:
# Beginning DSM Generations for 2192 QQuads
# [Parallel(n_jobs=7)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done   1 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=7)]: Done   2 tasks      | elapsed:   31.1s
# [Parallel(n_jobs=7)]: Done   3 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=7)]: Done   4 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=7)]: Done   5 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=7)]: Done   6 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=7)]: Done   7 tasks      | elapsed:   32.3s
# [Parallel(n_jobs=7)]: Done   8 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=7)]: Done   9 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=7)]: Done  10 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=7)]: Done  11 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=7)]: Done  12 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=7)]: Done  13 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=7)]: Done  14 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=7)]: Done  15 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=7)]: Done  16 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=7)]: Done  17 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=7)]: Done  18 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=7)]: Done  19 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=7)]: Done  20 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=7)]: Done  21 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=7)]: Done  22 tasks      | elapsed:  2.1min
# C:\Users\BenJames\anaconda3\envs\geospatial\lib\site-packages\joblib\externals\loky\process_executor.py:703: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=7)]: Done  23 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=7)]: Done  24 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=7)]: Done  25 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=7)]: Done  26 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=7)]: Done  27 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=7)]: Done  28 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=7)]: Done  29 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  30 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  31 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  32 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  33 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  34 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  35 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  37 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  38 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  39 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  40 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  41 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  42 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  43 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  44 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  45 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  46 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  47 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  48 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  49 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  50 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  51 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  52 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  53 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  54 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  55 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  56 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  57 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=7)]: Done  58 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=7)]: Done  59 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=7)]: Done  60 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=7)]: Done  61 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=7)]: Done  62 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=7)]: Done  63 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=7)]: Done  64 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=7)]: Done  65 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  66 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  67 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  68 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  69 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  70 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  71 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  72 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  73 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  74 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  75 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  76 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  77 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  78 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  79 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  80 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  81 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  82 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  83 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  84 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  85 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  86 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  87 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  88 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  89 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  90 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  91 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  92 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  93 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  94 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  95 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  96 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Batch computation too fast (0.1676s.) Setting batch_size=2.
# [Parallel(n_jobs=7)]: Done  97 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  98 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done  99 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 100 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 101 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 102 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 103 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 104 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 105 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 106 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 108 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Batch computation too fast (0.0070s.) Setting batch_size=4.
# [Parallel(n_jobs=7)]: Done 110 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 112 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 114 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 116 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 118 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 120 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 122 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 124 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 126 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 128 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 130 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 132 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 134 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 138 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Batch computation too fast (0.0070s.) Setting batch_size=8.
# [Parallel(n_jobs=7)]: Done 142 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 146 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 150 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 154 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 158 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 162 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 166 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 170 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 174 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 178 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 182 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 190 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 198 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Batch computation too fast (0.0080s.) Setting batch_size=16.
# [Parallel(n_jobs=7)]: Done 206 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 214 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 222 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 230 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 238 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 246 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 254 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 262 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 270 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 278 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 286 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 294 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 302 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 318 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Batch computation too fast (0.0080s.) Setting batch_size=32.
# [Parallel(n_jobs=7)]: Done 334 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 350 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 366 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 382 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 398 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 414 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 430 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 446 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 462 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 478 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 494 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 510 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 526 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 558 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Batch computation too fast (0.0070s.) Setting batch_size=64.
# [Parallel(n_jobs=7)]: Done 590 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 622 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 654 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 686 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 718 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 750 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 782 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 814 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 846 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 878 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 910 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 942 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 974 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1038 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Batch computation too fast (0.0120s.) Setting batch_size=128.
# [Parallel(n_jobs=7)]: Done 1102 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1166 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1230 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1294 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1358 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1422 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1486 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1550 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1614 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1678 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1742 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1806 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1870 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1874 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1878 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1882 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1886 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1890 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1894 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1898 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1902 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1906 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1910 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1914 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1918 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1922 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1926 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1930 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1934 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1938 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1942 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1946 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1950 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1954 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1958 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1962 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1966 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1970 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1974 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1978 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1982 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1986 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1990 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1994 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 1998 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2002 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2006 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2010 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2014 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2018 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2022 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2026 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2030 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2034 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2038 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2042 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2046 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2050 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2054 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2058 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2062 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2066 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2070 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2074 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2078 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2082 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2086 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2090 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2094 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2095 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 2096 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=7)]: Done 2097 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=7)]: Done 2098 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=7)]: Done 2099 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=7)]: Done 2100 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=7)]: Done 2104 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=7)]: Done 2108 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=7)]: Done 2112 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=7)]: Done 2116 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=7)]: Done 2120 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=7)]: Done 2124 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=7)]: Done 2128 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=7)]: Done 2132 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=7)]: Done 2136 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=7)]: Done 2140 tasks      | elapsed:  8.3min
# ...FINISHED
#
#
# Wall time: 12min 6s
# [Parallel(n_jobs=7)]: Done 2192 out of 2192 | elapsed: 12.1min finished

# %% [markdown]
# ## URBAN EXTENT

# %%
# %load_ext chime
import os
import pdal
import gdal
from datetime import datetime
import json
import rasterio as rio
from joblib import Parallel, delayed
import geopandas as gpd
import chime
# Out:
# The chime extension is already loaded. To reload it, use:
#   %reload_ext chime
# PROJ: proj_create_from_database: Cannot find proj.db

# %%
ugt_tindex_loc = r"E:/LAZIndex2019_UGTRGBFull.gpkg"
ugt_tindex = gpd.read_file(ugt_tindex_loc)#.to_crs("epsg:2868')

ortho_5ksubindex = r"M:\PAG2019\EPCExtent_30cm\Ortho_5kSubIndex.gpkg"
subIndex5k = gpd.read_file(ortho_5ksubindex)
#subIndex5k.head()

dsm40cm_loc = r"..\UrbanExtent_15cm\Elevation_40cmNPS\DSM40cm"

ugt_res = 0.4/0.3048

# %%
json_pipe_base = """{ "pipeline":
[ %s ]
}"""

json_reindex_base = """
    # %s
    {
        "type":"filters.merge"
    },
    {
        "type":"filters.crop",
        "polygon":"%s",
        "a_srs":"EPSG:2868"
    }"""

gdal_writer = """
    # %s,
    {
        "type":"writers.gdal",
        "filename": "%s",
        "resolution": %s,
        "window_size": %s,
        "nodata": 0,
        "output_type": "idw",
        "gdalopts":"TILED=YES, COMPRESS=LZW, "
    }
"""

def lazToDSM(row):    
    #for i, row in subIndex5k.iterrows():
    geom = row.geometry
    outfile_name = f"{row.path}_{row.row}_DSM40cm.tif"
    ofile = os.path.join(dsm40cm_loc, outfile_name)
    print(f"Starting {ofile} at {datetime.now()}")
    
    if not os.path.exists(ofile):
        geom_wkt = str(geom.wkt)

        lidar_tiles = ugt_tindex[ugt_tindex.geometry.intersects(geom)]
        if len(lidar_tiles) == 0:
            #continue
            return None

        files = '"' + '",\n"'.join([os.path.abspath(file).replace("\\","/") for file in lidar_tiles.location.values]) + '",'


        json_reindex = json_reindex_base % (files, geom_wkt)#, pdal_bounds_min, pdal_bounds_max
        create_dsm = gdal_writer % (json_reindex, ofile.replace("\\","/"), ugt_res, max(ugt_res * 2, 5))


        json_pipeline = json_pipe_base % create_dsm
        #print(json_pipeline)

        start = datetime.now()
        pipeline = pdal.Pipeline(json_pipeline)
        pipeline.loglevel = 8
        pipeline.execute()
        end = datetime.now()
        print(f"\tFinished with {ofile} - {end-start} elapsed")

        return ofile

# %%
def getToDo(df):
    existing_files = os.listdir(dsm40cm_loc)
    df["outfile"] = df.apply(lambda row: f"{row.path}_{row.row}_DSM40cm.tif", axis=1)
    df= df[~df.outfile.isin(existing_files)]
    del df["outfile"]
    return df

# %%
toDo = getToDo(subIndex5k)
completed_ugt = Parallel(n_jobs=5, max_nbytes=None, verbose=5)(delayed(lazToDSM)(r) for i,r in toDo.iterrows())
# %chime
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   8 tasks      | elapsed:  3.1min
# C:\Users\BenJames\anaconda3\envs\geospatial\lib\site-packages\joblib\externals\loky\process_executor.py:703: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=5)]: Done  62 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=5)]: Done 152 tasks      | elapsed: 40.6min
# [Parallel(n_jobs=5)]: Done 278 tasks      | elapsed: 72.7min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 121.2min
# [Parallel(n_jobs=5)]: Done 638 tasks      | elapsed: 173.6min
# [Parallel(n_jobs=5)]: Done 790 out of 790 | elapsed: 201.9min finished

# %%
def createDSM(file_dict, res, overwrite=False):
    infile = file_dict["in_file"]
    outfile = file_dict["out_file"]
    
    if os.path.exists(outfile) and not overwrite:
        return
  
    json_dsm = gdal_writer % (infile.replace("\\","/"), outfile.replace("\\","/"), res, max(res * 2,10))#, ox, oy)#, raswidth, rasheight)
    json_dsm = json_pipe_base % json_dsm
    
    pipeline = pdal.Pipeline(json_dsm)
    pipeline.loglevel = 8

    start = datetime.now()
    pipeline.execute()
    end = datetime.now()

    print(f"{datetime.now()}\t-\tFinished with {outfile} - {end-start} elapsed")
    
    
def mergeToTiles(row, out_dir, tindex):
    name = row.THEMENAME
    print(f"Starting {name} at {datetime.now()}")
    ofile = os.path.join(out_dir, name + ".laz")
    if not os.path.exists(ofile):
        try:
            geom = row.geometry
            buff_geom = box(*geom.buffer(100).bounds)
            geom_wkt = str(buff_geom.wkt)

            lidar_tiles = tindex[tindex.geometry.intersects(buff_geom)]
            files = ''
            for i in lidar_tiles.location.values:
                files += '"' + os.path.abspath(i).replace('\\','/') + '", '
            
            files = files[:-1]

            query = ""
            for idx, r in lidar_tiles.iterrows():
                query += f"ogc_fid = {idx} or "
            query = query[:-4]

            json_reindex = json_reindex_base % (files, geom_wkt, ofile.replace('\\','/'), "EPSG:2868")#, pdal_bounds_min, pdal_bounds_max
            json_reindex = json_pipe_base % json_reindex
            
            start = datetime.now()
            pipeline = pdal.Pipeline(json_reindex)
            pipeline.loglevel = 8
            pipeline.execute()
            end = datetime.now()
            #print(f"\tFinished with {row.THEMENAME} - {end-start} elapsed")
            
            return json_reindex
        
        except MemoryError:
            print(Back.RED + Fore.WHITE + f"Failed for {name}. \n{MemoryError}")
            return None

# %%
import os
import pdal
import gdal
from datetime import datetime
import json
import rasterio as rio
from joblib import Parallel, delayed
import time


ortho_folder = r"P:\GISLibrary\OrthoPhotos\Ortho2017\UrbanExtent_15cm\Orthos"
laz_folder = r"P:\GISLibrary\OrthoPhotos\Ortho2017\UrbanExtent_15cm\Elevation\RGB\Full_retiled"
dsm_folder = r"P:\GISLibrary\OrthoPhotos\Ortho2017\UrbanExtent_15cm\Elevation\DSM_2ft"
os.makedirs(dsm_folder, exist_ok=True)

resolution = 0.8/0.3048

infiles = []
for f in os.listdir(laz_folder):
    infile = os.path.join(laz_folder, f)
    outfile = os.path.join(dsm_folder, f.replace(".laz", "_DSM.tif"))
    if f.endswith(".laz") and not os.path.exists(outfile):
        files = {}
        files["in_file"] = infile
        files["out_file"] = outfile
        infiles.append(files)  

print("\nBeginning DSM Generations for {} QQuads\n".format(len(infiles)))
Parallel(n_jobs=5, max_nbytes=None, verbose=5)(delayed(createDSM)(f, resolution) for f in infiles)

for f in infiles:
    #if "E0980_N510_1" in f['out_file']:
    hour = int(datetime.strftime(datetime.now(), '%H'))
    """while hour > 9 and hour < 17:
        print("Pausing creation for 1 hours...")
        time.sleep(60*60)
        hour = int(datetime.strftime(datetime.now(), '%H'))"""
        
    createDSM(f)
    
print("\n\n...FINISHED\n\n")
# Out:
# Beginning DSM Generations for 217 QQuads
#
# 2019-12-17 09:57:24.591319	-	Finished with P:\GISLibrary\OrthoPhotos\Ortho2017\UrbanExtent_15cm\Elevation\DSM_2ft\E0920_N450_3_DSM.tif - 0:01:15.189486 elapsed
